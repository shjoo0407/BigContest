# %%
import pandas as pd

data = pd.read_csv('./merge_user_loan_4.csv')
pd.set_option('display.max_columns', None)
data
# Out:
#            신청서 번호              한도조회 일시  금융사 번호  상품 번호        승인한도  승인금리  \
# 0         1748340  2022-06-07 13:05:41       7    191  42000000.0  13.6
# 1         1748340  2022-06-07 13:05:41      25    169  24000000.0  17.9
# 2         1748340  2022-06-07 13:05:41       2      7  24000000.0  18.5
# 3         1748340  2022-06-07 13:05:41       4    268  29000000.0  10.8
# 4         1748340  2022-06-07 13:05:41      11    118   5000000.0  16.4
# ...           ...                  ...     ...    ...         ...   ...
# 10455660  1428218  2022-06-03 12:01:58      62    200   3000000.0  14.8
# 10455661  1428218  2022-06-03 12:01:49       2      7  40000000.0  11.8
# 10455662  1428218  2022-06-03 12:01:48      32    257  15000000.0   7.2
# 10455663  1428218  2022-06-03 12:01:48      33    110  44000000.0  13.5
# 10455664  1428218  2022-06-03 12:01:48       5    194  44000000.0   9.7
#
#           신청 여부(타겟)     유저 번호    생년월일   성별                 생성일시   신용점수  \
# ...

# %% [markdown]
# ### 대출을 많이 받은 사람의 신용점수 형태

# %%
data
# Out:
#            신청서 번호              한도조회 일시  금융사 번호  상품 번호        승인한도  승인금리  \
# 0         1748340  2022-06-07 13:05:41       7    191  42000000.0  13.6
# 1         1748340  2022-06-07 13:05:41      25    169  24000000.0  17.9
# 2         1748340  2022-06-07 13:05:41       2      7  24000000.0  18.5
# 3         1748340  2022-06-07 13:05:41       4    268  29000000.0  10.8
# 4         1748340  2022-06-07 13:05:41      11    118   5000000.0  16.4
# ...           ...                  ...     ...    ...         ...   ...
# 10455660  1428218  2022-06-03 12:01:58      62    200   3000000.0  14.8
# 10455661  1428218  2022-06-03 12:01:49       2      7  40000000.0  11.8
# 10455662  1428218  2022-06-03 12:01:48      32    257  15000000.0   7.2
# 10455663  1428218  2022-06-03 12:01:48      33    110  44000000.0  13.5
# 10455664  1428218  2022-06-03 12:01:48       5    194  44000000.0   9.7
#
#           신청 여부(타겟)     유저 번호    생년월일   성별                 생성일시   신용점수  \
# ...

# %%
data_o = data[data['신청 여부(타겟)']==1]
data_o[['유저 번호','신청 여부(타겟)']].value_counts()
# Out:
# 유저 번호     신청 여부(타겟)
# 271537.0  1.0          122
# 570403.0  1.0          115
# 179191.0  1.0           95
# 121641.0  1.0           94
# 164732.0  1.0           91
#                       ...
# 146353.0  1.0            1
# 636703.0  1.0            1
# 438732.0  1.0            1
# 146340.0  1.0            1
# 440000.0  1.0            1
# Length: 127059, dtype: int64

# %% [markdown]
# ### 대출을 가장 많이 받은 271537를 살펴봅시다

# %%
data[data['유저 번호']==271537]
# Out:
#            신청서 번호              한도조회 일시  금융사 번호  상품 번호        승인한도  승인금리  \
# 259639     622690  2022-04-29 20:20:18      36     60  48000000.0  15.4
# 259640    1120147  2022-04-29 19:29:41      46     49  17000000.0  14.5
# 259641     622690  2022-04-29 20:20:18      63    226   5000000.0  13.0
# 259642    1120147  2022-04-29 19:29:41      36     60  48000000.0  15.4
# 259643     877757  2022-04-29 21:01:56      10    149  44000000.0  13.9
# ...           ...                  ...     ...    ...         ...   ...
# 10392536  1347151  2022-05-09 01:34:51      36    103   8000000.0   6.8
# 10392537  1347151  2022-05-09 01:34:50      27    148   8000000.0   7.1
# 10392538  1347151  2022-05-09 01:34:50      38    134   8000000.0   7.7
# 10392539  1347151  2022-05-09 01:34:50      59    251   8000000.0   6.7
# 10392540  1347151  2022-05-09 01:34:51      33    189   8000000.0   7.9
#
#           신청 여부(타겟)     유저 번호    생년월일   성별                 생성일시   신용점수  \
# ...

# %%
# 각각 대출을 받았을 때, 신용점수를 살펴봅시다 !! 

data_o[data_o['유저 번호']==271537][['생성일시','기대출금액','기대출수','신용점수']].head(30)
# Out:
#                         생성일시        기대출금액  기대출수   신용점수
# 259639   2022-04-29 20:20:16  141000000.0   5.0  810.0
# 259646   2022-04-29 21:01:55  141000000.0   5.0  810.0
# 259648   2022-04-29 21:44:15  141000000.0   5.0  810.0
# 259661   2022-04-29 21:01:55  141000000.0   5.0  810.0
# 259665   2022-04-29 19:29:39  141000000.0   5.0  810.0
# 259667   2022-04-29 23:00:12  141000000.0   5.0  810.0
# 259673   2022-04-29 19:29:39  141000000.0   5.0  810.0
# 259675   2022-04-29 23:00:12  141000000.0   5.0  810.0
# 259678   2022-04-29 21:44:15  141000000.0   5.0  810.0
# 259680   2022-04-29 21:01:55  141000000.0   5.0  810.0
# 259691   2022-04-29 23:00:12  141000000.0   5.0  810.0
# 259692   2022-04-29 21:01:55  141000000.0   5.0  810.0
# 259712   2022-04-29 20:20:16  141000000.0   5.0  810.0
# 259718   2022-04-29 23:00:12  141000000.0   5.0  810.0
# 685717   2022-04-30 18:25:58  141000000.0   5.0  630.0
# 685721   2022-04-30 05:26:44  141000000.0   5.0  630.0
# ...

# %%
# 뭐야 갑자기 630 -> 810으로 떡상한 이유는?

data_o[(data_o['생성일시']<'2022-04-29 23:00:12')&(data_o['유저 번호']==271537)].sort_values(by='한도조회 일시')
# Out:
#           신청서 번호              한도조회 일시  금융사 번호  상품 번호        승인한도  승인금리  \
# 7808097   358538  2022-03-09 00:47:58      36    157  30000000.0  19.5
# 9903186   339465  2022-03-11 17:39:25      51    247  41000000.0  13.3
# 9903196   339465  2022-03-11 17:39:26      36    157  17000000.0  19.5
# 9903194    33678  2022-03-11 18:08:41      38    223  10000000.0  17.4
# 9903200    33678  2022-03-11 18:08:43      36    157  17000000.0  19.5
# 9903184    33678  2022-03-11 18:08:43      63    226  25000000.0  15.6
# 9903189  1712417  2022-03-11 18:53:09      17     19  25000000.0  12.9
# 9903193  1712417  2022-03-11 18:53:16      47    138  37000000.0  14.0
# 8363981  1361130  2022-03-18 02:31:29      29    265  20000000.0   8.5
# 3814414  1884771  2022-03-31 21:17:47      13    262  70000000.0  13.4
# 3814411  1884771  2022-03-31 21:17:47      29    265  49000000.0   6.9
# 3814401  1884771  2022-03-31 21:17:47      38    223  10000000.0  13.3
# ...

# %%
# 음..뭐지??
# 이유를 아시는 분은 연락 주시길 바랍니다..

# %% [markdown]
# ### 대출을 많이 받은 사람의 근로&고용형태

# %%
# 프리랜서인가? 싶었는데 
# top5 모두 직장가입자&정규직 이었음. 

data_o[data_o['유저 번호']==164732]


# 570403.0  1.0          115
# 179191.0  1.0           95
# 121641.0  1.0           94
# 164732.0  1.0           91
# Out:
#            신청서 번호              한도조회 일시  금융사 번호  상품 번호       승인한도  승인금리  \
# 580556     605512  2022-04-24 19:50:17      63    226  7000000.0  18.7
# 580557     291720  2022-04-24 09:13:17      63    226  5000000.0  18.7
# 580558     738489  2022-04-24 13:45:46      63    226  5000000.0  18.7
# 580559      25939  2022-04-24 19:54:07      63    226  9000000.0  18.7
# 596626     374986  2022-04-29 09:05:58      24    229  9000000.0   9.4
# ...           ...                  ...     ...    ...        ...   ...
# 10426404   889531  2022-05-09 16:07:58      23    236  8000000.0  15.5
# 10426405  1224810  2022-05-09 09:08:37      63    226  6000000.0  18.7
# 10426411   160152  2022-05-09 19:40:41      63    226  5000000.0  18.7
# 10426415   948741  2022-05-09 21:57:34      63    226  5000000.0  18.7
# 10426418  1224810  2022-05-09 09:08:49      23    108  8000000.0  16.1
#
#           신청 여부(타겟)     유저 번호    생년월일   성별                 생성일시   신용점수  \
# ...

# %% [markdown]
# ### 전체 어플 이용자의 고용형태

# %%
data['근로형태'].value_counts()

# 대부분 일반 직장가입자(4대보험O)
# Out:
# 직장가입자(4대보험O)    9157920
# 직장가입자(4대보험X)     454136
# 개인사업자            376602
# 프리랜서             242300
# 전문직              222344
# 기타소득               2363
# Name: 근로형태, dtype: int64

# %%
data[['근로형태','고용형태']].value_counts()
# Out:
# 근로형태          고용형태
# 직장가입자(4대보험O)  정규직     8198395
#               계약직      792817
# 직장가입자(4대보험X)  정규직      241410
# 프리랜서          기타       233221
# 개인사업자         정규직      202620
# 전문직           정규직      175614
# 개인사업자         기타       162025
# 직장가입자(4대보험X)  계약직      111405
# 직장가입자(4대보험O)  일용직       94706
#               기타        72002
# 직장가입자(4대보험X)  기타        64407
#               일용직       36914
# 전문직           계약직       29567
#               기타        10761
# 개인사업자         계약직        9390
# 전문직           일용직        6402
# 프리랜서          정규직        5050
#               계약직        3835
# 개인사업자         일용직        2567
# 기타소득          기타         1739
#               정규직         311
#               일용직         210
# 프리랜서          일용직         194
# 기타소득          계약직         103
# dtype: int64

# %% [markdown]
# ### 근로형태가 직장가입자 4대보험X와 O의 연봉 차이 -> 그냥 궁금하달까요..?

# %%
# 직장가입자(4대보험O)
data[data['근로형태']=='직장가입자(4대보험O)']['연소득'].mean()
# Out:
# 46754229.890630186

# %%
data[data['근로형태']=='직장가입자(4대보험X)']['연소득'].mean()
# Out:
# 35258973.082953125

# %%
# 약 1100 만원의 차이를 보임.. 
data_o['근로형태'].value_counts()
# Out:
# 직장가입자(4대보험O)    316310
# 직장가입자(4대보험X)     45607
# 개인사업자            29778
# 프리랜서             25352
# 전문직               6865
# 기타소득               279
# Name: 근로형태, dtype: int64

# %%
#  한꺼번에 구하기
pd.options.display.float_format = '{:.1f}'.format
data['연소득'].groupby(data['근로형태']).mean().sort_values( ascending=False)
# Out:
# 근로형태
# 개인사업자          71993452.0
# 전문직            57995907.2
# 직장가입자(4대보험O)   46754229.9
# 프리랜서           41417511.3
# 직장가입자(4대보험X)   35258973.1
# 기타소득           30920863.3
# Name: 연소득, dtype: float64

# %% [markdown]
# ### 개인 사업자의 대출 금액 -> 원래 개인 사업하면 대출 많이 받지 않나요?

# %%
data[data['근로형태']=='개인사업자']['신청 여부(타겟)'].value_counts()

# 아직 미완성
# Out:
# 0.0    250722
# 1.0     29778
# Name: 신청 여부(타겟), dtype: int64
